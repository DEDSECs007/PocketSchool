# %%
import os
from dotenv import load_dotenv
import google.generativeai as genai

# Load .env
load_dotenv()

# Activate Gemini API
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
# Out:
# Pocket School Setup Successful 🚀
